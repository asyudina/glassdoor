# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import time
import pandas as pd
from glassdoor_scraper import get_jobs

# %%
#This line will open a new chrome window and start the scraping.

df = get_jobs(driver_path = "/Users/anna.yudina/Downloads/notebooks/chromedriver",keyword = "seo",location = "united states" ,num_jobs = 15, verbose = False)
#df
# Out:
# Progress: 0/15
# Progress: 1/15
# Progress: 2/15
# Progress: 3/15
# Progress: 4/15
# Progress: 5/15
# Progress: 6/15
# Progress: 7/15
# Progress: 8/15
# Progress: 9/15
# Progress: 10/15
# Progress: 11/15
# Progress: 12/15
# Progress: 13/15
# Progress: 14/15
# Progress: 15/15

# %%
df
# Out:
#                                             Job Title  \
# 0                                  Senior SEO Analyst
# 1                              REMOTE Sr. SEO Manager
# 2                                            SEO Lead
# 3                                      SEO Strategist
# 4                                      SEO Specialist
# 5                   Senior Search Manager - SEO & SEM
# 6                                 SEO and PPC Manager
# 7                                      SEO Copywriter
# 8                                      SEO/SEM Expert
# 9                                      SEO Specialist
# 10  Communication Content Manager - SEO/SocialM/Pr...
# 11                                     SEO Specialist
# 12                                     SEO Strategist
# 13                             SEO Manager - Services
# 14                                           SEO Lead
#
#                        Salary Estimate  \
# 0                                   -1
# ...

# %%
df.to_csv('example_glassdoor.csv')
